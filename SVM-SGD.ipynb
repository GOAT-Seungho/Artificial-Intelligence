# %%
import numpy as np
from sklearn.base import BaseEstimator, ClassifierMixin
class MBSGDClassifier(BaseEstimator, ClassifierMixin):
    """ Mini-Batch Stochastic Gradient Descent
    
    매개변수
    -------
    learning_rate : float 
        학습률 (0.0 과 1.0 사이)
    max_iter : int (default = 100)
        훈련 데이터셋 최대 반복 횟수
    batch_size : int (defalut = 32)
        Mini-Batch 
        
        
    속성
    ------
    w_ : 1d-array
        학습된 가중치
    b_ : float?
        학습된 편향(bias)
    """
    
    def __init__(self, batch_size=32, max_iter=100):
        
        
        
    def fit(self, X, y):
        # Fill
        self.w_ = np.zeros(len(X[0])) # 무작위 초기화가 필요한가?
        self.b_ = 0                   # 무작위 초기화가 필요한가?
        
        # theta = np.zeros((X.shape[1], 1)) 
        # error_list = [] 
        
        for e in range(self.max_iter):
            mini_batchs = create_mini_batches(X, y, batch_size)
            for mini_batch in mini_batches:
                X_mini, y_mini = mini_batch
                
                if (y_mini)
                F_prime_w = 
                F_prime_b = 
                # theta = theta - learning_rate * gradient(X_mini, y_mini, theta) 
                # error_list.append(cost(X_mini, y_mini, theta)) 
                
            w = w - learning_rate * 
            b = b - learning_rate * 
            ## ASd
                
                
        
        for i, val in enumerate(X):
            self.out.append(np.dot(X[i], self.w) + self.b)
            
        return self
        # theta, error_list
        
        
        
        
        
        
        
    
    # function to create a list containing mini-batches 
    def create_mini_batches(X, y, batch_size): 
        mini_batches = []
        data = np.hstack((X, y)) 
        np.random.shuffle(data) 
        n_minibatches = data.shape[0] // batch_size 
        i = 0

        for i in range(n_minibatches + 1): 
            mini_batch = data[i * batch_size:(i + 1)*batch_size, :] 
            X_mini = mini_batch[:, :-1] 
            Y_mini = mini_batch[:, -1].reshape((-1, 1)) 
            mini_batches.append((X_mini, Y_mini)) 
        if data.shape[0] % batch_size != 0: 
            mini_batch = data[i * batch_size:data.shape[0]] 
            X_mini = mini_batch[:, :-1] 
            Y_mini = mini_batch[:, -1].reshape((-1, 1)) 
            mini_batches.append((X_mini, Y_mini)) 
        return mini_batches
# Out:
#   File "<ipython-input-1-5adc25a5089e>", line 18
#     def fit(self, X, y):
#       ^
# IndentationError: expected an indented block
